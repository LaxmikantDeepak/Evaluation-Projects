# %% [markdown]
# # Baseball Case Study Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('baseball.csv')

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Here we can find
# overview about the data

# %% [markdown]
# # Null Values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
plt.figure(figsize=(17,10))
sns.heatmap(df.corr(),linewidth=0.1,vmax=1,annot=True)
plt.show()

# %% [markdown]
# There is no null values in this dataset

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(17,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can find the relation between variables it shows the how target variable will change after change in input variable....Target variable is W and we can see the relation of w with other variables.......The light shade shows the positive relationship where dark shade shows the negative relationship

# %%
plt.figure(figsize=(17,10))
sns.boxplot(df.W)
# Out:
# <AxesSubplot:xlabel='W'>

# %%
plt.figure(figsize=(17,10))
sns.boxplot(df.ERA)
# Out:
# <AxesSubplot:xlabel='ERA'>

# %%
plt.figure(figsize=(17,10))
plt.hist((df.E))
# Out:
# (array([5., 1., 9., 6., 2., 1., 0., 1., 3., 2.]),
#  array([ 75. ,  80.1,  85.2,  90.3,  95.4, 100.5, 105.6, 110.7, 115.8,
#         120.9, 126. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(15,10))
plt.hist(df.ER,bins=10)
# Out:
# (array([1., 1., 4., 5., 3., 7., 6., 0., 2., 1.]),
#  array([478. , 510.1, 542.2, 574.3, 606.4, 638.5, 670.6, 702.7, 734.8,
#         766.9, 799. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(df.W,df.ERA)
# Out:
# <AxesSubplot:xlabel='W', ylabel='ERA'>

# %% [markdown]
# it shows the negative relation between these 2 variable...if ERA decrease then W will also Decrease

# %%
plt.figure(figsize=(15,10))
sns.barplot(df.W,df.CG)
# Out:
# <AxesSubplot:xlabel='W', ylabel='CG'>

# %%
sns.jointplot(df.W,df.R)

# %%
sns.pairplot(df)

# %% [markdown]
# In this pair plot we can see the relationship of each variable with all other variables

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
outliers=np.abs(zscore(df))
print(np.where(outliers>3))
thresold=3
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(outliers<3).all(axis=1)]

# %%
df.shape
# Out:
# (30, 17)

# %%
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# 1 row is removed as it includes outliers in it

# %% [markdown]
# # Skewness

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# For a good model the skewness should be bellow 0.55...but in this data some variables are positively skeweed we have to make them normal by using log transformation

# %%
for col in df_new.columns:
    if df_new.skew().loc[col]>0.55:
        df_new[col]=np.log1p(df_new[col])

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.275681
# SHO    0.526943
# SV     0.109983
# E      0.586101
# dtype: float64

# %% [markdown]
# now all the variables are normally distributed

# %% [markdown]
# # Setting the X and Y variable

# %%
x=df_new.iloc[:,1:]

# %%
x.shape
# Out:
# (29, 16)

# %%
y=df_new.iloc[:,0]

# %%
y.shape
# Out:
# (29,)

# %%
y=y.values.reshape(y.shape[0],1)

# %%
y.shape
# Out:
# (29, 1)

# %% [markdown]
# # StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=scale.fit_transform(x)

# %%
x.shape
# Out:
# (29, 16)

# %% [markdown]
# # Regression Process

# %% [markdown]
# In this dataset the target variable is Continuous variable so that the regression process should be implimented

# %%
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
def max_r2_score(rgr,x,y):
    max_score=0
    for r in range(42,101):
        
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=r)
        rgr.fit(x_train,y_train)
        pred=rgr.predict(x_test)
        r_sc=r2_score(y_test,pred)
        if r_sc>max_score:
            max_score=r_sc
            r_state=r
            
    print('max score at random_state of',r_state,'is',max_score)
    return r_state

# %%
lr=LinearRegression()
sc=max_r2_score(lr,x,y)
# Out:
# max score at random_state of 73 is 0.8507709590470474

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=73)
lr.fit(x_train,y_train)
pred=lr.predict(x_test)

# %%
pred_y=lr.predict(x_train)
r2_score(y_train,pred_y)
# Out:
# 0.9590789448735081

# %%
print(r2_score(y_test,pred))
print('\n')
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.8507709590470474
#
#
# RMSE 4.453653185120049

# %%
score=cross_val_score(lr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.5578333  -0.36011946  0.61092665 -0.22451215 -0.38019605]
# 0.04078645834637891
# 0.44737734920591826

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
lsr=Lasso()
pr={'alpha':[.0001,.001,.01,.1,1]}
gs=GridSearchCV(lsr,pr,cv=5)
gs.fit(x,y)
gs.best_params_
# Out:
# {'alpha': 1}

# %%
lsr=Lasso(alpha=1)
sc=max_r2_score(lsr,x,y)
# Out:
# max score at random_state of 82 is 0.9569861780928952

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=82)
lsr.fit(x_train,y_train)
pred=lsr.predict(x_test)

# %%
print(r2_score(y_test,pred))
print('\n')
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.9569861780928952
#
#
# RMSE 1.7736919521580372

# %%
score=cross_val_score(lsr,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.73540561 -0.70591176  0.75373286  0.78816503  0.8802995 ]
# 0.49033824821340977
# 0.6002031960611405

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
pr={'n_neighbors':range(1,20)}
gs=GridSearchCV(knn,pr,cv=5)
gs.fit(x,y)
gs.best_params_
# Out:
# {'n_neighbors': 5}

# %%
knn=KNeighborsRegressor(n_neighbors=5)
sc=max_r2_score(knn,x,y)
# Out:
# max score at random_state of 51 is 0.7973065326633166

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=51)
knn.fit(x_train,y_train)
pred=knn.predict(x_test)

# %%
print(r2_score(y_test,pred))
print('\n')
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.7973065326633166
#
#
# RMSE 4.099593475781064

# %%
score=cross_val_score(knn,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.00863636 -1.46526316  0.47636972  0.31416393  0.80165094]
# 0.027111560669320613
# 0.7888810870744435

# %% [markdown]
# # AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor()
pr={'learning_rate':[.001,.01,.1,1],'n_estimators':[10,100,500,1000],'base_estimator':[lr,lsr,knn]}
gs=GridSearchCV(ada,pr,cv=5)
gs.fit(x,y)
gs.best_params_
# Out:
# {'base_estimator': LinearRegression(),
#  'learning_rate': 0.1,
#  'n_estimators': 1000}

# %%
ada=AdaBoostRegressor(base_estimator=lsr,learning_rate=0.1,n_estimators=1000)
sc=max_r2_score(ada,x,y)
# Out:
# max score at random_state of 46 is 0.9184262449824416

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=82)
ada.fit(x_train,y_train)
pred=ada.predict(x_test)

# %%
print(r2_score(y_test,pred))
print('\n')
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.9709118348167499
#
#
# RMSE 1.4585870153403178

# %%
score=cross_val_score(ada,x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.687268   -1.15044141  0.77393259  0.68290893  0.92155732]
# 0.38304508501837287
# 0.7716008297284196

# %% [markdown]
# # Model selection

# %% [markdown]
# In all above models the Lasso regression model is performing very well in this dataset so we select the Lasso regression as final model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=82)
lsr.fit(x_train,y_train)
pred=lsr.predict(x_test)

# %%
print(r2_score(y_test,pred))
print('\n')
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.9569861780928952
#
#
# RMSE 1.7736919521580372

# %%
pred_data=pd.DataFrame(pred)
pred_data.to_csv('lasso_pred_data')

# %%
pred_y=lsr.predict(x_train)
r2_score(y_train,pred_y)
# Out:
# 0.8805535604100494

# %% [markdown]
# there is no underfitting and overfittinf in this dataset

# %% [markdown]
# ## Best Model is Lasso Model

# %%
import joblib

# %%
joblib.dump(lsr,'lasso_model_baseball_project.obj')
# Out:
# ['lasso_model_baseball_project.obj']
